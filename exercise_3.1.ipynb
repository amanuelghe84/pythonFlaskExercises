# %% [markdown]
# ## Flask Projects with Web and RESTful APIs
#
# ### 1. **To-Do App**
#
# #### RESTful API Features:
# - **GET /todos**: Retrieve all to-do items.
# - **POST /todos**: Add a new to-do item.
# - **PUT /todos/<id>**: Update a specific to-do item.
# - **DELETE /todos/<id>**: Delete a specific to-do item.
# - **GET /todos/<id>**: Retrieve a specific to-do item.
#
# #### Model:
# - **Todo**: Represents a single to-do item.
#   - `id`: Unique identifier for the to-do.
#   - `task`: Description of the to-do.
#   - `is_completed`: Boolean indicating whether the to-do is completed.
#
# ---

# %%
# !pip  install flask --break-system-packages
# !pip  install flask-restx  --break-system-packages
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: flask in /home/aman/.local/lib/python3.11/site-packages (3.1.0)
# Requirement already satisfied: Werkzeug>=3.1 in /home/aman/.local/lib/python3.11/site-packages (from flask) (3.1.3)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/aman/.local/lib/python3.11/site-packages (from flask) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /home/aman/.local/lib/python3.11/site-packages (from flask) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/aman/.local/lib/python3.11/site-packages (from flask) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /home/aman/.local/lib/python3.11/site-packages (from flask) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /home/aman/.local/lib/python3.11/site-packages (from Jinja2>=3.1.2->flask) (3.0.2)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: flask-restx in /home/aman/.local/lib/python3.11/site-packages (1.3.0)
# Requirement already satisfied: aniso8601>=0.82 in /home/aman/.local/lib/python3.11/site-packages (from flask-restx) (9.0.1)
# Requirement already satisfied: jsonschema in /home/aman/.local/lib/python3.11/site-packages (from flask-restx) (4.23.0)
# Requirement already satisfied: Flask!=2.0.0,>=0.8 in /home/aman/.local/lib/python3.11/site-packages (from flask-restx) (3.1.0)
# Requirement already satisfied: werkzeug!=2.0.0 in /home/aman/.local/lib/python3.11/site-packages (from flask-restx) (3.1.3)
# Requirement already satisfied: pytz in /home/aman/.local/lib/python3.11/site-packages (from flask-restx) (2024.2)
# Requirement already satisfied: importlib-resources in /home/aman/.local/lib/python3.11/site-packages (from flask-restx) (6.4.5)
# Requirement already satisfied: Jinja2>=3.1.2 in /home/aman/.local/lib/python3.11/site-packages (from Flask!=2.0.0,>=0.8->flask-restx) (3.1.4)
# Requirement already satisfied: itsdangerous>=2.2 in /home/aman/.local/lib/python3.11/site-packages (from Flask!=2.0.0,>=0.8->flask-restx) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in /home/aman/.local/lib/python3.11/site-packages (from Flask!=2.0.0,>=0.8->flask-restx) (8.1.8)
# Requirement already satisfied: blinker>=1.9 in /home/aman/.local/lib/python3.11/site-packages (from Flask!=2.0.0,>=0.8->flask-restx) (1.9.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/aman/.local/lib/python3.11/site-packages (from werkzeug!=2.0.0->flask-restx) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in /home/aman/.local/lib/python3.11/site-packages (from jsonschema->flask-restx) (24.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /home/aman/.local/lib/python3.11/site-packages (from jsonschema->flask-restx) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in /home/aman/.local/lib/python3.11/site-packages (from jsonschema->flask-restx) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /home/aman/.local/lib/python3.11/site-packages (from jsonschema->flask-restx) (0.22.3)

# %%
from http import HTTPStatus
import nest_asyncio
from flask import Flask, jsonify, request, Blueprint
from werkzeug.serving import run_simple

# Allow Flask to run in a Jupyter Notebook
nest_asyncio.apply()

# Initialize Flask app
app = Flask(__name__)

# In-memory storage for to-do tasks
todos = {} 

todos_bp = Blueprint('todos', __name__ ,url_prefix='/todo')


@todos_bp.route('/todos/<int:todo_id>', methods=["GET"])
def get_todo(todo_id: int):
    if todo_id not in todos:
        response_message = {"error": "Post not found"}
        response_status_code = HTTPStatus.NOT_FOUND
        
        return jsonify(response_message), response_status_code
    
    response_message = {"id": todo_id, "todo": todos[todo_id]}
    response_status_code = HTTPStatus.OK
    
    return jsonify(response_message), response_status_code


@todos_bp.route('/todos', methods=["POST"])
def create_todo():
    data = request.get__json() # Get Json payload from request
    
    if not data or 'id' not in data or 'task' not in data:
        response_message = {"error": "Invalid input"}
        response_status_code = HTTPStatus.BAD_REQUEST
        
        return jsonify(response_message), response_status_code
    
    todo_id = data['id']
    todo_task = data['task']
    todo_is_completed = data['is_completed']
    
    if todo_id in todos:
        response_message = {"error": "Todo with this ID already exists"}
        response_status_code = HTTPStatus.CONFLICT
        
        return jsonify(response_message), response_status_code


@todos_bp.route('/todos/<int:todo_id>', methods=["PUT"])
def update_todo(todo_id: int):
    if todo_id not in todos:
        response_message = {"error": "Post not found"}
        response_status_code = HTTPStatus.NOT_FOUND
        
        return jsonify(response_message), response_status_code
    
    data = request.get_json()
    
    if not data or 'id' not in data or 'task' not in data:
        response_message = {"error": "Invalid input"}
        response_status_code = HTTPStatus.BAD_REQUEST
        
        return jsonify(response_message), response_status_code
    
    todos[todo_id] = {"task": data['task'], "is_completed": data['is_completed']}
    
    response_message ={"id": todo_id, "todo": todos[todo_id]}
    response_status_code = HTTPStatus.OK
    
    return jsonify(response_message), response_status_code

@todos_bp.route('/todos/<int:todo_id>', methods=["DELETE"])
def delete_todo(todo_id: int):
    if todo_id not in todos:
        response_message = {"error": "Post not found"}
        response_status_code = HTTPStatus.NOT_FOUND
        
        return jsonify(response_message), response_status_code
    
    del todos[todo_id]
    
    response_message = {"success": "Post deleted"}
    response_status_code =HTTPStatus.NO_CONTENT
    
    return jsonify(response_message), response_status_code


@todos_bp.route('', methods=["GET"])
def create_todo():
    data = request.get_json()
    
    if not data or 'id' not in data or 'task' not in data:
        response_message = {"error": "Invalid input"}
        response_status_code = HTTPStatus.BAD_REQUEST
        
        return jsonify(response_message), response_status_code
    
    todo_id = data['id']
    todo_task = data['task']
    todo_is_completed = data['is_completed']
    
    if todo_id in todos:
        response_message = {"error": "Todo with this ID already exists"}
        response_status_code = HTTPStatus.CONFLICT
        
        return jsonify(response_message), response_status_code






app.register_blueprint(todos_bp)


run_simple('localhost', 5000, app)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[7], line 117
#     108         response_status_code = HTTPStatus.CONFLICT
#     110         return jsonify(response_message), response_status_code
# --> 117 app.register_blueprint(todos_bp)
#     120 run_simple('localhost', 5000, app)
#
# File ~/.local/lib/python3.11/site-packages/flask/sansio/scaffold.py:47, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      45 def wrapper_func(self: Scaffold, *args: t.Any, **kwargs: t.Any) -> t.Any:
#      46     self._check_setup_finished(f_name)
# ---> 47     return f(self, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/flask/sansio/app.py:595, in App.register_blueprint(self, blueprint, **options)
#     569 @setupmethod
#     570 def register_blueprint(self, blueprint: Blueprint, **options: t.Any) -> None:
#     571     """Register a :class:`~flask.Blueprint` on the application. Keyword
#     572     arguments passed to this method will override the defaults set on the
#     573     blueprint.
#    (...)
#     593     .. versionadded:: 0.7
#     594     """
# --> 595     blueprint.register(self, options)
#
# File ~/.local/lib/python3.11/site-packages/flask/sansio/blueprints.py:335, in Blueprint.register(self, app, options)
#     332     self._merge_blueprint_funcs(app, name)
#     334 for deferred in self.deferred_functions:
# --> 335     deferred(state)
#     337 cli_resolved_group = options.get("cli_group", self.cli_group)
#     339 if self.cli.commands:
#
# File ~/.local/lib/python3.11/site-packages/flask/sansio/blueprints.py:434, in Blueprint.add_url_rule.<locals>.<lambda>(s)
#     430 if view_func and hasattr(view_func, "__name__") and "." in view_func.__name__:
#     431     raise ValueError("'view_func' name may not contain a dot '.' character.")
#     433 self.record(
# --> 434     lambda s: s.add_url_rule(
#     435         rule,
#     436         endpoint,
#     437         view_func,
#     438         provide_automatic_options=provide_automatic_options,
#     439         **options,
#     440     )
#     441 )
#
# File ~/.local/lib/python3.11/site-packages/flask/sansio/blueprints.py:110, in BlueprintSetupState.add_url_rule(self, rule, endpoint, view_func, **options)
#     107 if "defaults" in options:
#     108     defaults = dict(defaults, **options.pop("defaults"))
# --> 110 self.app.add_url_rule(
#     111     rule,
#     112     f"{self.name_prefix}.{self.name}.{endpoint}".lstrip("."),
#     113     view_func,
#     114     defaults=defaults,
#     115     **options,
#     116 )
#
# File ~/.local/lib/python3.11/site-packages/flask/sansio/scaffold.py:47, in setupmethod.<locals>.wrapper_func(self, *args, **kwargs)
#      45 def wrapper_func(self: Scaffold, *args: t.Any, **kwargs: t.Any) -> t.Any:
#      46     self._check_setup_finished(f_name)
# ---> 47     return f(self, *args, **kwargs)
#
# File ~/.local/lib/python3.11/site-packages/flask/sansio/app.py:657, in App.add_url_rule(self, rule, endpoint, view_func, provide_automatic_options, **options)
#     655 old_func = self.view_functions.get(endpoint)
#     656 if old_func is not None and old_func != view_func:
# --> 657     raise AssertionError(
#     658         "View function mapping is overwriting an existing"
#     659         f" endpoint function: {endpoint}"
#     660     )
#     661 self.view_functions[endpoint] = view_func
#
# AssertionError: View function mapping is overwriting an existing endpoint function: todos.create_todo
